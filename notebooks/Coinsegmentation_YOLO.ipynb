# %% [markdown]
# ##Prepare Dataset

# %% [markdown]
# get datasets from ROBOFLOW

# %%
# !pip install roboflow

from google.colab import userdata
from roboflow import Roboflow

rf = Roboflow(api_key=userdata.get('ROBOFLOW_API_KEY'))
project = rf.workspace("datamodel-fhfwy").project("coinsegment")
version = project.version(4)
dataset = version.download("yolov8")

# %% [markdown]
# ##Prepare YOLO

# %%
# !pip install ultralytics

# %% [markdown]
# ##Train Custom Datasets

# %% [markdown]
# use dataset from Roboflow with pre-train model *yolo26s-seg* and image size of 1024x1024 pixel for indepth image detail

# %%
# Start training from a pretrained *.pt model
# !yolo segment train data="/content/CoinSegment-4/data.yaml" model=yolo26s-seg.pt epochs=100 imgsz=1024 augment=True patience=20 batch=4

# %% [markdown]
# ##Show Training result

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/segment/train2/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/segment/train2/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/segment/train2/MaskF1_curve.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/content/runs/segment/train2/train_batch0.jpg', width=600)
